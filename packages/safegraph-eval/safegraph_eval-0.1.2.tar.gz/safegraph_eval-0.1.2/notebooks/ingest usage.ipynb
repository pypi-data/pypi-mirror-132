# %% [markdown]
# # Instructions
#
# 1. Download any sample from Shop and move it into a _separate_ folder locally.
# 2. Pass the path for that folder as the `path=` argument for `read_sg_shop_zipfile()`.
# 3. Specify whether you also want to read any supplement files using the `return_supplemental_files` parameter.

# %%
from safegraph_eval import ingest

# %% [markdown]
# # Read multiple months of Patterns/Core/Geo

# %%
nested_dir = '/Users/eugene/Documents/Projects/safegraph_eval_dir/sample_data/multiple_months_zipped_patterns_core_geo/'

# %%
output = ingest.read_sg_shop_zipfile(nested_dir, return_supplemental_files = True)

# %%
output.keys()
# Out:
# dict_keys(['data', 'brand_info', 'normalization_stats', 'visit_panel_summary', 'home_panel_summary'])

# %%
output['data'].head()
# Out:
#               placekey      parent_placekey  \
# 0  zzw-224@62j-shz-qpv  zzw-223@62j-shz-rrk
# 1  zzw-226@62j-shx-bp9                  NaN
# 2  23f-222@62j-shy-zvf                  NaN
# 3  222-222@62j-sgh-z2k                  NaN
# 4  zzw-225@62j-sj3-nt9  zzw-223@62j-sj3-p7q
#
#                          safegraph_brand_ids                location_name  \
# 0                                        NaN           Rowes Wharf Garage
# 1  SG_BRAND_73971897e96ce01fa107640e730f905a              Bank of America
# 2                                        NaN  SP Parking Chinatown Garage
# 3                                        NaN              Simmons College
# 4  SG_BRAND_28a17457e5bc33c99581072edfe18a6a         People's United Bank
#
#                  brands                                      top_category  \
# 0                   NaN                           Other Personal Services
# 1       Bank of America                  Depository Credit Intermediation
# ...

# %%
output['brand_info'].head()
# Out:
#                           safegraph_brand_id       brand_name  \
# 0                  SG_BRAND_1ec16189589a76ef  & Other Stories
# 1  SG_BRAND_12b20c8402b220acfe0e65dd113dbbc7           &pizza
# 2                  SG_BRAND_6462594f4a598a94         1 Hotels
# 3  SG_BRAND_407913c3eaadbdf961cbb276649f6618    1-800-Flowers
# 4                  SG_BRAND_8889b7aefb6aa0c9           1-Stop
#
#    parent_safegraph_brand_id naics_code                         top_category  \
# 0                        NaN     448120                      Clothing Stores
# 1                        NaN     722511  Restaurants and Other Eating Places
# 2                        NaN     721110               Traveler Accommodation
# 3                        NaN     453110                             Florists
# 4  SG_BRAND_424a47b33a953161     445120                       Grocery Stores
#
#                                sub_category stock_symbol stock_exchange  \
# ...

# %% [markdown]
# # Read one month of Patterns/Core/Geo

# %%
unnested_dir = '/Users/eugene/Documents/Projects/safegraph_eval_dir/sample_data/one_month_zipped_patterns_core/'

# %%
output = read_sg_shop_zipfile(unnested_dir, return_supplemental_files = True)

# %%
output['data'].head()
# Out:
#               placekey parent_placekey       location_name  \
# 0  23p-222@628-pgh-5zz             NaN           Thoro Ent
# 1  zzz-222@628-pnx-psq             NaN  Hancock Playground
# 2  22t-222@628-pmd-vzz             NaN          Salon Bass
# 3  23w-222@628-pm4-dgk             NaN       Kenneth Heist
# 4  227-222@63s-dw8-4d9             NaN       Penrose Plaza
#
#   safegraph_brand_ids brands                               top_category  \
# 0                 NaN    NaN                 Sound Recording Industries
# 1                 NaN    NaN  Other Amusement and Recreation Industries
# 2                 NaN    NaN                     Personal Care Services
# 3                 NaN    NaN                      Offices of Physicians
# 4                 NaN    NaN                     Lessors of Real Estate
#
#                                         sub_category category_tags naics_code  \
# 0                            Sound Recording Studios           NaN     512240
# ...

# %% [markdown]
# # Read Core

# %%
unnested_core_dir = '/Users/eugene/Documents/Projects/safegraph_eval_dir/sample_data/zipped_core/'

# %%
output = read_sg_shop_zipfile(unnested_core_dir, return_supplemental_files = True)

# %%
output['data'].head()
# Out:
#               placekey      parent_placekey             location_name  \
# 0  228-222@5x4-4b5-wtv  225-222@5x4-4b5-wtv       Anoosh Afifi MS DDS
# 1  222-222@5x4-4qy-y9z                  NaN          Angela Sonia LMP
# 2  22d-222@5x4-4nz-rc5                  NaN     The Donlin Apartments
# 3  223-222@5x4-49c-47q  zzz-222@5x4-47y-28v  Tennis Center Sand Point
# 4  zzw-222@5x4-4vy-47q  zzz-222@5x4-4vy-47q           The Gold Thread
#
#   safegraph_brand_ids brands  \
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2                 NaN    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN
#
#                                         top_category  \
# 0                                Offices of Dentists
# 1                             Personal Care Services
# 2                             Lessors of Real Estate
# 3          Other Amusement and Recreation Industries
# 4  Personal and Household Goods Repair and Mainte...
#
# ...

# %%
output['brand_info'].head()
# Out:
#                           safegraph_brand_id       brand_name  \
# 0                  SG_BRAND_1ec16189589a76ef  & Other Stories
# 1  SG_BRAND_12b20c8402b220acfe0e65dd113dbbc7           &pizza
# 2                  SG_BRAND_6462594f4a598a94         1 Hotels
# 3  SG_BRAND_407913c3eaadbdf961cbb276649f6618    1-800-Flowers
# 4                  SG_BRAND_8889b7aefb6aa0c9           1-Stop
#
#    parent_safegraph_brand_id naics_code                         top_category  \
# 0                        NaN     448120                      Clothing Stores
# 1                        NaN     722511  Restaurants and Other Eating Places
# 2                        NaN     721110               Traveler Accommodation
# 3                        NaN     453110                             Florists
# 4  SG_BRAND_424a47b33a953161     445120                       Grocery Stores
#
#                                sub_category stock_symbol stock_exchange  \
# ...
