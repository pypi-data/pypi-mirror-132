# %% [markdown]
# # Filtering Outlier POI from Patterns

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
from src.safegraph_eval.preprocessing import preprocessing

# %%
# ingest sample Monthly Patterns data from lowe's for 2021 Jan to Sep downloaded from shop
# https://shop.safegraph.com/?brands=SG_BRAND_4f8a39fb928268edb1ab256922e436d7&countries=US&poi=ALL&tab=datasets&cart=sg_p-202100-202108
patterns = pd.DataFrame()
for month in range(1,10,1):
    _ = pd.read_csv(f"data/Lowes-PATTERNS-2021_0{month}-2021-10-28/patterns.csv")
    patterns = patterns.append(_,ignore_index=True)

# %%
display(patterns.head()) # each row is Patterns data for a Lowe's POI for a specific month
# Out:
#               placekey parent_placekey location_name          street_address  \
# 0  222-222@5wg-42f-5vf             NaN        Lowe's           925 E 17th St
# 1  222-222@5r8-dy2-vvf             NaN        Lowe's      2205 SE Adams Blvd
# 2  zzw-222@8g7-nkk-zfz             NaN        Lowe's       3341 Lexington Rd
# 3  zzw-222@3bt-by7-2c5             NaN        Lowe's          333 E Tudor Rd
# 4  222-222@8sz-9cw-bc5             NaN        Lowe's  605 SW H K Dodgen Loop
#
#            city region  postal_code  \
# 0   Idaho Falls     ID        83404
# 1  Bartlesville     OK        74006
# 2        Athens     GA        30605
# 3     Anchorage     AK        99503
# 4        Temple     TX        76502
#
#                          safegraph_brand_ids  brands  \
# 0  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
# 1  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
# 2  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
# 3  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
# 4  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
#
#             date_range_start  ...  \
# 0  2021-01-01T00:00:00-07:00  ...
# 1  2021-01-01T00:00:00-06:00  ...
# 2  2021-01-01T00:00:00-05:00  ...
# 3  2021-01-01T00:00:00-09:00  ...
# 4  2021-01-01T00:00:00-06:00  ...
#
#                                 visitor_daytime_cbgs  \
# 0  {"160199705011":39,"160199704031":36,"16051960...
# 1  {"401139400033":8,"401139400041":7,"4014700050...
# 2  {"132219602023":60,"132219602013":54,"13221960...
# 3  {"020200023011":12,"020200018024":10,"02020000...
# 4  {"480270213031":94,"480270203002":84,"48027020...
#
#    visitor_country_of_origin  distance_from_home median_dwell  \
# 0                {"US":1090}             13121.0         21.0
# 1                 {"US":106}             13246.0         24.0
# 2                {"US":1295}             16266.0         21.0
# 3                 {"US":459}              6470.0         21.0
# 4                {"US":1961}             13110.0         22.0
#
#                                 bucketed_dwell_times  \
# 0  {"<5":36,"5-10":434,"11-20":500,"21-60":731,"6...
# 1  {"<5":5,"5-10":38,"11-20":34,"21-60":59,"61-12...
# 2  {"<5":59,"5-10":482,"11-20":556,"21-60":849,"6...
# 3  {"<5":14,"5-10":187,"11-20":196,"21-60":290,"6...
# 4  {"<5":75,"5-10":786,"11-20":817,"21-60":1404,"...
#
#                               related_same_day_brand  \
# 0  {"The Home Depot":15,"Walmart":13,"Sam's Club"...
# 1  {"Russell Cellular":30,"Walmart":13,"QuikTrip"...
# 2  {"Walmart":11,"Kroger":5,"Goodwill Industries"...
# 3  {"The Home Depot":11,"Walmart":8,"Holiday Stat...
# 4  {"Walmart":13,"H-E-B":8,"The Home Depot":8,"CE...
#
#                             related_same_month_brand  \
# 0  {"Walmart":70,"The Home Depot":39,"McDonald's"...
# 1  {"Walmart":72,"Russell Cellular":65,"Sonic":45...
# 2  {"Walmart":59,"Chick-fil-A":42,"Kroger":41,"Mc...
# 3  {"Walmart":48,"Costco":48,"The Home Depot":40,...
# 4  {"Walmart":69,"H-E-B":61,"CEFCO":44,"McDonald'...
#
#                                   popularity_by_hour  \
# 0  [21,19,15,14,10,13,17,71,139,168,233,304,319,3...
# 1  [6,6,6,4,3,3,11,15,25,36,31,34,42,36,38,30,23,...
# 2  [40,42,40,46,54,66,72,100,189,247,348,364,376,...
# 3  [5,6,6,7,7,13,34,41,72,74,91,113,154,146,113,1...
# 4  [58,58,64,62,65,90,110,175,299,416,563,642,696...
#
#                                    popularity_by_day  \
# 0  {"Monday":211,"Tuesday":196,"Wednesday":205,"T...
# 1  {"Monday":27,"Tuesday":28,"Wednesday":31,"Thur...
# 2  {"Monday":271,"Tuesday":255,"Wednesday":275,"T...
# 3  {"Monday":93,"Tuesday":100,"Wednesday":120,"Th...
# 4  {"Monday":479,"Tuesday":409,"Wednesday":392,"T...
#
#                   device_type
# 0   {"android":739,"ios":384}
# 1     {"android":99,"ios":12}
# 2   {"android":641,"ios":692}
# 3   {"android":226,"ios":250}
# 4  {"android":1062,"ios":972}
#
# [5 rows x 27 columns]

# %%
# How many unique Lowe's have Patterns for this time period?
patterns["placekey"].drop_duplicates().size
# Out:
# 1706

# %%
print(preprocessing.label_and_remove_outliers_iqr.__doc__)
# Out:
#     Label outliers in Patterns using k*IQR filtering, by group, and optionally remove them.
#     If remove, POIs with values in any month that are determined as outliers are removed.
#     Returns a DataFrame.
#
#     Parameters:
#         df_ (pandas DataFrame): DataFrame containing SafeGraph Patterns data.
#         group_column (str): The SafeGraph column that will be used to group the data (e.g., safegraph_brand_ids). Outliers are determined based in the distribution of values in each group.
#         column_to_filter (str): The SafeGraph column on which perform the outlier filtering (e.g., raw_visit_counts).
#     Optional Parameters:
#         k (float): Value that will be multiplied by the interquartile range to determine outliers. Defaults to 1.5.
#         remove (bool): Whether or not to remove the outlier rows from the returned DataFrame. Defaults to True.
#         verbose (bool): If True, prints how many POI were removed as outliers. Defaults to True.
#         brand_whitelist (list): List of safegraph_brand_ids to omit from the outlier filter. Defaults to an empty list.
#         placekey_whitelist (list): List of placekeys to omit from the outlier filter. Defaults to an empty list.

# %%
patterns_filtered_default_params = preprocessing.label_and_remove_outliers_iqr(
    patterns, group_column = "brands", column_to_filter = "raw_visit_counts")
display(patterns_filtered_default_params.head())
# Out:
# 135 POI out of 1706 were removed as outliers.
#               placekey      parent_placekey location_name      street_address  \
# 0  222-222@5wg-42f-5vf                  NaN        Lowe's       925 E 17th St
# 1  222-222@5r8-dy2-vvf                  NaN        Lowe's  2205 SE Adams Blvd
# 2  zzw-222@8g7-nkk-zfz                  NaN        Lowe's   3341 Lexington Rd
# 3  zzw-222@3bt-by7-2c5                  NaN        Lowe's      333 E Tudor Rd
# 5  222-222@5z4-qrt-wff  zzw-222@5z4-qrt-w49        Lowe's   29335 Central Ave
#
#             city region  postal_code  \
# 0    Idaho Falls     ID        83404
# 1   Bartlesville     OK        74006
# 2         Athens     GA        30605
# 3      Anchorage     AK        99503
# 5  Lake Elsinore     CA        92532
#
#                          safegraph_brand_ids  brands  \
# 0  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
# 1  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
# 2  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
# 3  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
# 5  SG_BRAND_4f8a39fb928268edb1ab256922e436d7  Lowe's
#
#             date_range_start  ...  \
# 0  2021-01-01T00:00:00-07:00  ...
# 1  2021-01-01T00:00:00-06:00  ...
# 2  2021-01-01T00:00:00-05:00  ...
# 3  2021-01-01T00:00:00-09:00  ...
# 5  2021-01-01T00:00:00-08:00  ...
#
#                                 visitor_daytime_cbgs  \
# 0  {"160199705011":39,"160199704031":36,"16051960...
# 1  {"401139400033":8,"401139400041":7,"4014700050...
# 2  {"132219602023":60,"132219602013":54,"13221960...
# 3  {"020200023011":12,"020200018024":10,"02020000...
# 5  {"060650427153":71,"060650430011":43,"06065042...
#
#    visitor_country_of_origin  distance_from_home median_dwell  \
# 0                {"US":1090}             13121.0         21.0
# 1                 {"US":106}             13246.0         24.0
# 2                {"US":1295}             16266.0         21.0
# 3                 {"US":459}              6470.0         21.0
# 5                 {"US":947}              8548.0         20.0
#
#                                 bucketed_dwell_times  \
# 0  {"<5":36,"5-10":434,"11-20":500,"21-60":731,"6...
# 1  {"<5":5,"5-10":38,"11-20":34,"21-60":59,"61-12...
# 2  {"<5":59,"5-10":482,"11-20":556,"21-60":849,"6...
# 3  {"<5":14,"5-10":187,"11-20":196,"21-60":290,"6...
# 5  {"<5":40,"5-10":362,"11-20":393,"21-60":457,"6...
#
#                               related_same_day_brand  \
# 0  {"The Home Depot":15,"Walmart":13,"Sam's Club"...
# 1  {"Russell Cellular":30,"Walmart":13,"QuikTrip"...
# 2  {"Walmart":11,"Kroger":5,"Goodwill Industries"...
# 3  {"The Home Depot":11,"Walmart":8,"Holiday Stat...
# 5  {"Costco":17,"The Home Depot":10,"Starbucks":6...
#
#                             related_same_month_brand  \
# 0  {"Walmart":70,"The Home Depot":39,"McDonald's"...
# 1  {"Walmart":72,"Russell Cellular":65,"Sonic":45...
# 2  {"Walmart":59,"Chick-fil-A":42,"Kroger":41,"Mc...
# 3  {"Walmart":48,"Costco":48,"The Home Depot":40,...
# 5  {"Costco":52,"Starbucks":45,"The Home Depot":4...
#
#                                   popularity_by_hour  \
# 0  [21,19,15,14,10,13,17,71,139,168,233,304,319,3...
# 1  [6,6,6,4,3,3,11,15,25,36,31,34,42,36,38,30,23,...
# 2  [40,42,40,46,54,66,72,100,189,247,348,364,376,...
# 3  [5,6,6,7,7,13,34,41,72,74,91,113,154,146,113,1...
# 5  [7,8,8,4,6,23,47,64,113,155,238,257,258,282,27...
# 8785   2021-06-01T00:00:00-05:00  18375 Wright St  Omaha     NE
# 10340  2021-07-01T00:00:00-05:00  18375 Wright St  Omaha     NE
# 12116  2021-08-01T00:00:00-05:00  18375 Wright St  Omaha     NE
# 13924  2021-09-01T00:00:00-05:00  18375 Wright St  Omaha     NE
#
#        raw_visit_counts
# 464                2550
# 2360               2048
# 3898               3199
# 5446               3934
# 7122               5143
# 8785               3588
# 10340              3161
# 12116              2810
# 13924              2615

# %%
# Let's say we think these are valid and want to increase the bound of what is considered an "outlier".

# We can increase the k parameter in the filtering function from 1.5 which is the default.
patterns_filtered_higher_k = preprocessing.label_and_remove_outliers_iqr(
    patterns, group_column = "brands", column_to_filter = "raw_visit_counts", k = 2)
# Out:
# 60 POI out of 1706 were removed as outliers.

# %%
# Which plackeys were removed this time?
removed_pks_higher_k = set(patterns["placekey"]).difference(patterns_filtered_higher_k["placekey"])
print(removed_pks_higher_k)
# Out:
# {'zzw-222@5pq-928-w6k', 'zzw-222@8sr-858-n3q', 'zzw-222@8gg-sm2-w49', '222-222@8gm-mqz-ch5', '222-222@8fc-mpn-3kf', '222-222@5qs-vx6-249', 'zzw-222@8gk-tbc-y5f', 'zzw-222@5pm-hvv-wx5', '222-222@5pn-mqv-hqz', '222-222@8fc-r4x-dqf', '222-222@647-2wc-whq', '222-222@8f2-rtk-zj9', 'zzw-222@5qw-5f6-7t9', '222-222@8dy-eh9-xnq', 'zzw-222@5pn-6qr-m6k', '222-222@8f2-qp6-cbk', '222-222@5pm-fpw-ch5', '222-222@8f6-sk4-2c5', '222-222@8gm-zd5-99f', '222-222@8f2-55m-r6k', 'zzw-222@5ps-78z-j35', '222-223@5pn-r25-rkz', '222-222@8g8-7v2-389', '222-222@5pn-4bm-hkf', 'zzy-222@8f3-nxy-2p9', '222-222@8dy-ssp-h5z', 'zzw-222@8f3-fwj-2ff', '222-222@5qy-dxp-8jv', 'zzw-222@8dj-ds7-c3q', '222-222@8gn-kkm-cbk', 'zzw-222@5r2-mxn-hbk', '222-222@5pv-9wp-9mk', 'zzw-222@5pn-xqw-hyv', '222-222@5r7-chn-9cq', '222-222@5r7-fr7-8sq', '222-222@5pt-4pw-y35', 'zzw-222@8g8-4jz-wtv', 'zzw-222@5r4-2t7-swk', '222-222@8gh-x7p-rkz', '222-222@8gg-r84-4y9', '222-222@8g9-693-w49', '222-222@8gk-yjz-ty9', '222-222@8gg-9tn-5xq', 'zzw-222@8gg-d7p-6c5', '222-222@5pm-h48-nqz', '222-223@5qw-7h5-vxq', 'zzw-222@8gm-dtb-rrk', '222-222@5r6-t7m-fmk', '222-222@8f3-jdq-bc5', '222-222@8gm-t6g-q2k', '222-222@8gm-nfr-2hq', 'zzw-222@8f2-2wy-y5f', '222-222@5qt-3fg-whq', '223-222@8fc-rkm-kj9', 'zzw-222@5ps-9vr-qxq', '222-222@5pr-32g-n3q', '222-222@8gh-tnj-kxq', '222-222@8sv-4tf-wc5', 'zzw-222@5r7-zxb-26k', '222-222@5qs-w33-2hq'}

# %%
# The original placekey from Omaha NE is no longer removed.
"222-222@5p2-2tw-vs5" in removed_pks_higher_k
# Out:
# False
