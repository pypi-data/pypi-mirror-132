# %% [markdown]
# # Demo

# %%
# !pip install tai-chi-engine

# %% [markdown]
# ## Probable other dependencies
# transformers==4.12.3

# %%
from forgebox.imports import *
from tai_chi_engine import TaiChiEngine

# %% [markdown]
# ## Demo tasks

# %% [markdown]
# > Load all the code above in one shot, the demo starts here

# %%
def df_creator_image_folder(path: Path) -> pd.DataFrame:
    """
    Create a dataframe ,
    Which list all the image path under a system folder
    """
    path = Path(path)
    files = []
    formats = ["jpg", "jpeg", "png"]
    for fmt in formats:
        files.extend(path.rglob(f"*.{fmt.lower()}"))
        files.extend(path.rglob(f"*.{fmt.upper()}"))
    return pd.DataFrame({"path": files}).sample(frac=1.).reset_index(drop=True)

# %% [markdown]
# ### Choose dataset

# %%
# BEAR_DATASET = HOME/"Downloads"/"bear_dataset"
DATA = Path("/GCI/data")
BEAR_DATASET = DATA/"bear_dataset"
ROTTEN_TOMATOES = DATA/"rttmt"
NETFLIX = DATA/"nf"

# %% [markdown]
# Choose one of the following to run

# %% [markdown]
# #### Netflix 📺

# %%
base_df = pd.read_csv(NETFLIX/"netflix_titles.csv")
base_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# #### The bear 🐻

# %%
base_df = df_creator_image_folder(BEAR_DATASET)
base_df
# Out:
#                                             path
# 0     /GCI/data/bear_dataset/teddys/00000198.jpg
# 1    /GCI/data/bear_dataset/grizzly/00000189.jpg
# 2    /GCI/data/bear_dataset/teddys/00000117.jpeg
# 3     /GCI/data/bear_dataset/teddys/00000013.jpg
# 4     /GCI/data/bear_dataset/teddys/00000022.png
# ..                                           ...
# 517  /GCI/data/bear_dataset/grizzly/00000111.jpg
# 518   /GCI/data/bear_dataset/teddys/00000158.jpg
# 519   /GCI/data/bear_dataset/teddys/00000065.jpg
# 520    /GCI/data/bear_dataset/black/00000021.jpg
# 521    /GCI/data/bear_dataset/black/00000070.jpg
#
# [522 rows x 1 columns]

# %% [markdown]
# #### The rotten tomatoes 🍅 🎬

# %%
# the rotten tomatoes dataset, we are not using every line

base_df = pd.read_csv(ROTTEN_TOMATOES/'critic_reviews.csv', nrows=200000)
base_df = base_df[~base_df['review_score'].isna()].reset_index(drop=True)
base_df = base_df[~base_df['review_content'].isna()].reset_index(drop=True)
base_df = base_df[~base_df['critic_name'].isna()].reset_index(drop=True)

base_df = base_df[base_df['review_score'].apply(lambda x: "/" in x)].reset_index(drop=True)

base_df['review_score'] = base_df['review_score'].apply(eval)

base_df
# Out:
#        rotten_tomatoes_link       critic_name  top_critic  \
# 0                 m/0814255      Ben McEachen       False
# 1                 m/0814255      Nick Schager       False
# 2                 m/0814255  Bill Goodykoontz        True
# 3                 m/0814255      Jim Schembri        True
# 4                 m/0814255        Mark Adams       False
# ...                     ...               ...         ...
# 108237       m/bottle_shock   Phil Villarreal       False
# 108238       m/bottle_shock    Todd Gilchrist       False
# 108239       m/bottle_shock    Austin Kennedy       False
# 108240       m/bottle_shock     Sean P. Means       False
# 108241       m/bottle_shock      Pete Hammond       False
#
#                  publisher_name review_type  review_score review_date  \
# 0       Sunday Mail (Australia)       Fresh         0.700  2010-02-09
# 1                Slant Magazine      Rotten         0.250  2010-02-10
# 2              Arizona Republic       Fresh         0.700  2010-02-10
# 3           The Age (Australia)       Fresh         0.600  2010-02-10
# 4             Daily Mirror (UK)       Fresh         0.800  2010-02-10
# ...                         ...         ...           ...         ...
# 108237       Arizona Daily Star      Rotten         0.500  2008-08-29
# 108238               IGN Movies      Rotten         0.400  2008-08-29
# 108239             Sin Magazine      Rotten         0.625  2008-09-02
# 108240        Salt Lake Tribune      Rotten         0.500  2008-09-05
# 108241            Hollywood.com       Fresh         0.800  2008-10-01
#
#                                            review_content
# 0       Whether audiences will get behind The Lightnin...
# 1       Harry Potter knockoffs don't come more transpa...
# 2       Percy Jackson isn't a great movie, but it's a ...
# 3       Crammed with dragons, set-destroying fights an...
# 4       This action-packed fantasy adventure, based on...
# ...                                                   ...
# 108237  It might have worked better as a documentary, ...
# 108238  Bottle Shock feels more like an excuse to exer...
# 108239  I was slightly involved towards the end, but t...
# 108240          Flat, musty and with a hint of flopsweat.
# 108241         One of the year's most entertaining films.
#
# [108242 rows x 8 columns]

# %% [markdown]
# ### Start of the pipeline

# %% [markdown]
# Initiate the ```phase``` to track the configuration

# %%
# PROJECT = Path("./project")
# PROJECT = Path("./project/image_regression")
# PROJECT = Path("./project/rotten1")
# PROJECT = Path("./project/rotten_text")
# PROJECT = Path("./project/netflix")
# PROJECT = Path("./project0")
PROJECT = Path("./project3")

engine = TaiChiEngine(base_df, project = PROJECT)

# %%
engine()
# Out:
# Output()
# HTML(value='')
# <h3>522 rows of data, example table</h3>
#                                             path
# 92     /GCI/data/bear_dataset/black/00000061.jpg
# 160  /GCI/data/bear_dataset/grizzly/00000159.jpg
# 14   /GCI/data/bear_dataset/grizzly/00000032.jpg
# 176  /GCI/data/bear_dataset/grizzly/00000194.jpg
# 433    /GCI/data/bear_dataset/black/00000014.jpg
# HTML(value='<hr>')
# EditableList(layout=Layout(width='100%'))
# interactive(children=(Dropdown(description='src', options=('[all_columns]', 'path'), value='[all_columns]'), B…

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
# !conda install -n base -c conda-forge jupyterlab_widgets
# !conda install -n py36 -c conda-forge ipywidgets
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistenc-
#
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.1=py_0
#   - conda-forge/linux-64::oslo.utils==3.41.0=py37_0
#   - defaults/noarch::dask==2.11.0=py_0
#   - defaults/linux-64::conda-package-handling==1.6.0=py37h7b6447c_0
#   - conda-forge/noarch::oslo.config==8.2.0=py_0
#   - defaults/noarch::prompt_toolkit==3.0.3=py_0
#   - conda-forge/noarch::oslo.i18n==5.0.1=py_0
#   - conda-forge/noarch::python-keystoneclient==4.2.0=pyhd8ed1ab_0
#   - defaults/linux-64::pytest-remotedata==0.3.2=py37_0
#   - defaults/noarch::numpydoc==0.9.2=py_0
#   - conda-forge/noarch::os-service-types==1.7.0=pyh9f0ad1d_0
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/linux-64::numpy==1.18.1=py37h4f9e942_0
#   - defaults/linux-64::notebook==6.0.3=py37_0
#   - defaults/linux-64::numba==0.48.0=py37h0573a6f_0
#   - defaults/linux-64::ipykernel==5.1.4=py37h39e3cac_0
#   - defaults/linux-64::pytest==5.3.5=py37_0
#   - defaults/noarch::pygments==2.5.2=py_0
#   - defaults/linux-64::jupyter==1.0.0=py37_7
#   - conda-forge/noarch::oauth2client==4.1.3=py_0
#   - defaults/linux-64::clyent==1.2.2=py37_1
#   - defaults/noarch::pytest-astropy-header==0.1.2=py_0
#   - conda-forge/noarch::pbr==5.5.1=pyh9f0ad1d_0
#   - defaults/linux-64::anaconda-client==1.7.2=py37_0
#   - defaults/noarch::pytest-doctestplus==0.5.0=py_0
#   - conda-forge/linux-64::sregistry-swift==0.2.35=py37hc8dfbb8_0
#   - conda-forge/linux-64::conda==4.9.2=py37h89c1867_0
#   - defaults/linux-64::nbconvert==5.6.1=py37_0
#   - defaults/linux-64::bokeh==1.4.0=py37_0
#   - defaults/noarch::nbformat==5.0.4=py_0
#   - defaults/linux-64::mkl_random==1.1.0=py37hd6b4f25_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py37_0
#   - conda-forge/linux-64::sregistry==0.2.35=py37hc8dfbb8_0
#   - defaults/linux-64::pytest-arraydiff==0.3=py37h39e3cac_0
#   - defaults/linux-64::anaconda-navigator==1.9.12=py37_0
#   - defaults/linux-64::patsy==0.5.1=py37_0
#   - defaults/linux-64::h5py==2.10.0=py37h7918eee_0
#   - defaults/linux-64::distributed==2.11.0=py37_0
#   - defaults/noarch::jupyter_console==6.1.0=py_0
#   - defaults/noarch::seaborn==0.10.0=py_0
#   - defaults/linux-64::pytables==3.6.1=py37h71ec239_0
#   - defaults/noarch::pytest-astropy==0.8.0=py_0
#   - defaults/linux-64::ipython==7.12.0=py37h5ca1d4c_0
#   - defaults/linux-64::bottleneck==1.3.2=py37heb32a55_0
#   - defaults/noarch::joblib==0.14.1=py_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/linux-64::nose==1.3.7=py37_2
#   - defaults/linux-64::requests==2.22.0=py37_1
#   - defaults/linux-64::imageio==2.6.1=py37_0
#   - conda-forge/noarch::python-swiftclient==3.11.0=pyhd8ed1ab_0
#   - defaults/noarch::qtconsole==4.6.0=py_1
#   - defaults/linux-64::mkl_fft==1.0.15=py37ha843d7b_0
#   - defaults/linux-64::scikit-image==0.16.2=py37h0573a6f_0
#   - conda-forge/noarch::oslo.serialization==4.0.1=py_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/noarch::jupyterlab_server==1.0.6=py_0
#   - defaults/linux-64::pywavelets==1.1.1=py37h7b6447c_0
#   - conda-forge/noarch::keystoneauth1==4.3.0=pyhd8ed1ab_0
#   - defaults/linux-64::matplotlib==3.1.3=py37_0
#   - conda-forge/noarch::debtcollector==2.2.0=py_0
#   - defaults/noarch::babel==2.8.0=py_0
#   - defaults/linux-64::_ipyw_jlab_nb_ext_conf==0.1.0=py37_0
#   - defaults/linux-64::numexpr==2.7.1=py37h423224d_0
#   - defaults/noarch::jinja2==2.11.1=py_0
#   - conda-forge/noarch::stevedore==2.0.1=py_0
#   - defaults/linux-64::astropy==4.0=py37h7b6447c_0
#   - defaults/linux-64::sympy==1.5.1=py37_0
#   - defaults/linux-64::bleach==3.1.0=py37_0
#   - defaults/noarch::pytest-openfiles==0.4.0=py_0
#   - defaults/noarch::networkx==2.4=py_0
#   - defaults/linux-64::anaconda==2020.02=py37_0
#   - defaults/noarch::flask==1.1.1=py_0
#   - defaults/noarch::jupyterlab==1.2.6=pyhf63ae98_0
#   - defaults/linux-64::cython==0.29.15=py37he6710b0_0
#   - defaults/linux-64::conda-build==3.18.11=py37_0
#   - defaults/linux-64::scipy==1.4.1=py37h0b6359f_0
#   - defaults/linux-64::wheel==0.34.2=py37_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - defaults/linux-64::statsmodels==0.11.0=py37h7b6447c_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
# Collecting package metadata (repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.1=py_0
#   - conda-forge/linux-64::oslo.utils==3.41.0=py37_0
#   - defaults/noarch::dask==2.11.0=py_0
#   - defaults/linux-64::conda-package-handling==1.6.0=py37h7b6447c_0
#   - conda-forge/noarch::oslo.config==8.2.0=py_0
#   - defaults/noarch::prompt_toolkit==3.0.3=py_0
#   - conda-forge/noarch::oslo.i18n==5.0.1=py_0
#   - conda-forge/noarch::python-keystoneclient==4.2.0=pyhd8ed1ab_0
#   - defaults/linux-64::pytest-remotedata==0.3.2=py37_0
#   - defaults/noarch::numpydoc==0.9.2=py_0
#   - conda-forge/noarch::os-service-types==1.7.0=pyh9f0ad1d_0
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/linux-64::numpy==1.18.1=py37h4f9e942_0
#   - defaults/linux-64::notebook==6.0.3=py37_0
#   - defaults/linux-64::numba==0.48.0=py37h0573a6f_0
#   - defaults/linux-64::ipykernel==5.1.4=py37h39e3cac_0
#   - defaults/linux-64::pytest==5.3.5=py37_0
#   - defaults/noarch::pygments==2.5.2=py_0
#   - defaults/linux-64::jupyter==1.0.0=py37_7
#   - conda-forge/noarch::oauth2client==4.1.3=py_0
#   - defaults/linux-64::clyent==1.2.2=py37_1
#   - defaults/noarch::pytest-astropy-header==0.1.2=py_0
#   - conda-forge/noarch::pbr==5.5.1=pyh9f0ad1d_0
#   - defaults/linux-64::anaconda-client==1.7.2=py37_0
#   - defaults/noarch::pytest-doctestplus==0.5.0=py_0
#   - conda-forge/linux-64::sregistry-swift==0.2.35=py37hc8dfbb8_0
#   - conda-forge/linux-64::conda==4.9.2=py37h89c1867_0
#   - defaults/linux-64::nbconvert==5.6.1=py37_0
#   - defaults/linux-64::bokeh==1.4.0=py37_0
#   - defaults/noarch::nbformat==5.0.4=py_0
#   - defaults/linux-64::mkl_random==1.1.0=py37hd6b4f25_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py37_0
#   - conda-forge/linux-64::sregistry==0.2.35=py37hc8dfbb8_0
#   - defaults/linux-64::pytest-arraydiff==0.3=py37h39e3cac_0
#   - defaults/linux-64::anaconda-navigator==1.9.12=py37_0
#   - defaults/linux-64::patsy==0.5.1=py37_0
#   - defaults/linux-64::h5py==2.10.0=py37h7918eee_0
#   - defaults/linux-64::distributed==2.11.0=py37_0
#   - defaults/noarch::jupyter_console==6.1.0=py_0
#   - defaults/noarch::seaborn==0.10.0=py_0
#   - defaults/linux-64::pytables==3.6.1=py37h71ec239_0
#   - defaults/noarch::pytest-astropy==0.8.0=py_0
#   - defaults/linux-64::ipython==7.12.0=py37h5ca1d4c_0
#   - defaults/linux-64::bottleneck==1.3.2=py37heb32a55_0
#   - defaults/noarch::joblib==0.14.1=py_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/linux-64::nose==1.3.7=py37_2
#   - defaults/linux-64::requests==2.22.0=py37_1
#   - defaults/linux-64::imageio==2.6.1=py37_0
#   - conda-forge/noarch::python-swiftclient==3.11.0=pyhd8ed1ab_0
#   - defaults/noarch::qtconsole==4.6.0=py_1
#   - defaults/linux-64::mkl_fft==1.0.15=py37ha843d7b_0
#   - defaults/linux-64::scikit-image==0.16.2=py37h0573a6f_0
#   - conda-forge/noarch::oslo.serialization==4.0.1=py_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/noarch::jupyterlab_server==1.0.6=py_0
#   - defaults/linux-64::pywavelets==1.1.1=py37h7b6447c_0
#   - conda-forge/noarch::keystoneauth1==4.3.0=pyhd8ed1ab_0
#   - defaults/linux-64::matplotlib==3.1.3=py37_0
#   - conda-forge/noarch::debtcollector==2.2.0=py_0
#   - defaults/noarch::babel==2.8.0=py_0
#   - defaults/linux-64::_ipyw_jlab_nb_ext_conf==0.1.0=py37_0
#   - defaults/linux-64::numexpr==2.7.1=py37h423224d_0
#   - defaults/noarch::jinja2==2.11.1=py_0
#   - conda-forge/noarch::stevedore==2.0.1=py_0
#   - defaults/linux-64::astropy==4.0=py37h7b6447c_0
#   - defaults/linux-64::sympy==1.5.1=py37_0
#   - defaults/linux-64::bleach==3.1.0=py37_0
#   - defaults/noarch::pytest-openfiles==0.4.0=py_0
#   - defaults/noarch::networkx==2.4=py_0
#   - defaults/linux-64::anaconda==2020.02=py37_0
#   - defaults/noarch::flask==1.1.1=py_0
#   - defaults/noarch::jupyterlab==1.2.6=pyhf63ae98_0
#   - defaults/linux-64::cython==0.29.15=py37he6710b0_0
#   - defaults/linux-64::conda-build==3.18.11=py37_0
#   - defaults/linux-64::scipy==1.4.1=py37h0b6359f_0
#   - defaults/linux-64::wheel==0.34.2=py37_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - defaults/linux-64::statsmodels==0.11.0=py37h7b6447c_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /anaconda3
#
#   added / updated specs:
#     - jupyterlab_widgets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astroid-2.9.0              |   py37h89c1867_0         347 KB  conda-forge
#     certifi-2021.10.8          |   py37h89c1867_1         145 KB  conda-forge
#     docutils-0.18.1            |   py37h89c1867_0         737 KB  conda-forge
#     fsspec-2021.11.1           |     pyhd8ed1ab_0          91 KB  conda-forge
#     importlib-metadata-4.10.0  |   py37h89c1867_0          32 KB  conda-forge
#     isort-5.10.1               |     pyhd8ed1ab_0          79 KB  conda-forge
#     jsonschema-4.1.2           |     pyhd8ed1ab_0          54 KB  conda-forge
#     jupyterlab_widgets-1.0.2   |     pyhd8ed1ab_0         130 KB  conda-forge
#     pip-21.3.1                 |     pyhd8ed1ab_0         1.2 MB  conda-forge
#     pylint-2.12.2              |     pyhd8ed1ab_0         264 KB  conda-forge
#     rsa-4.8                    |     pyhd8ed1ab_0          31 KB  conda-forge
#     setuptools-60.1.0          |   py37h89c1867_0         1.0 MB  conda-forge
#     typing-extensions-4.0.1    |       hd8ed1ab_0           8 KB  conda-forge
#     typing_extensions-4.0.1    |     pyha770c72_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/linux-64::_anaconda_depends-2020.02-py37_0
#   astroid            conda-forge/linux-64::astroid-2.9.0-py37h89c1867_0
#   autopep8           conda-forge/noarch::autopep8-1.5.6-pyhd8ed1ab_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py37hb5d75c8_1001
#   docutils           conda-forge/linux-64::docutils-0.18.1-py37h89c1867_0
#   flake8             conda-forge/noarch::flake8-3.8.4-py_0
#   fsspec             conda-forge/noarch::fsspec-2021.11.1-pyhd8ed1ab_0
#   importlib-metadata conda-forge/linux-64::importlib-metadata-4.10.0-py37h89c1867_0
#   isort              conda-forge/noarch::isort-5.10.1-pyhd8ed1ab_0
#   jedi               conda-forge/linux-64::jedi-0.17.1-py37hc8dfbb8_0
#   jsonschema         conda-forge/noarch::jsonschema-4.1.2-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-1.0.2-pyhd8ed1ab_0
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.1.3-py37hef1b27d_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.18.1-py37hde5b4d6_1
#   pandas             conda-forge/linux-64::pandas-1.1.4-py37h10a2094_0
#   parso              conda-forge/noarch::parso-0.7.0-pyh9f0ad1d_0
#   pillow             pkgs/main/linux-64::pillow-7.1.2-py37hb39fc2d_0
#   pip                conda-forge/noarch::pip-21.3.1-pyhd8ed1ab_0
#   platformdirs       conda-forge/noarch::platformdirs-2.3.0-pyhd8ed1ab_0
#   psutil             conda-forge/linux-64::psutil-5.7.3-py37hb5d75c8_0
#   pycodestyle        conda-forge/noarch::pycodestyle-2.6.0-pyh9f0ad1d_0
#   pyflakes           conda-forge/noarch::pyflakes-2.2.0-pyh9f0ad1d_0
#   pylint             conda-forge/noarch::pylint-2.12.2-pyhd8ed1ab_0
#   python-language-s~ conda-forge/linux-64::python-language-server-0.34.1-py37hc8dfbb8_0
#   pytz               conda-forge/noarch::pytz-2021.3-pyhd8ed1ab_0
#   rsa                conda-forge/noarch::rsa-4.8-pyhd8ed1ab_0
#   scikit-learn       pkgs/main/linux-64::scikit-learn-0.24.2-py37ha9443f7_0
#   setuptools         conda-forge/linux-64::setuptools-60.1.0-py37h89c1867_0
#   spyder             conda-forge/linux-64::spyder-4.1.5-py37hc8dfbb8_0
#   spyder-kernels     conda-forge/linux-64::spyder-kernels-1.9.4-py37hc8dfbb8_0
#   sqlalchemy         conda-forge/linux-64::sqlalchemy-1.3.20-py37h8f50634_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.0.0-pyh8a188c0_0
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_0
#   tqdm               conda-forge/noarch::tqdm-4.62.3-pyhd8ed1ab_0
#   typed-ast          conda-forge/linux-64::typed-ast-1.4.1-py37h4abf009_1
#   typing-extensions  conda-forge/noarch::typing-extensions-4.0.1-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.0.1-pyha770c72_0
#   urllib3            conda-forge/noarch::urllib3-1.25.11-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2021.10.8-ha878542_0
#   certifi              pkgs/main::certifi-2019.11.28-py37_0 --> conda-forge::certifi-2021.10.8-py37h89c1867_1
#   openssl              pkgs/main::openssl-1.1.1d-h7b6447c_4 --> conda-forge::openssl-1.1.1h-h516909a_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2020.02-py37_0 --> custom-py37_1
#
#
# Proceed ([y]/n)?
